# %% [markdown]
# <a href="https://colab.research.google.com/github/ekramasif/Basic-Computer-Vision/blob/main/Image_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
# LOAD AN IMAGE USING 'IMREAD'
img = cv2.imread("/content/drive/MyDrive/Datasets/img2.jpg")
# DISPLAY
cv2_imshow(img)
height,width = img.shape[:2]
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F228CA9BF90>

# %% [markdown]
# ## Affine Transform

# %%
Tx,Ty =height/4,width/4
T = np.float32([[1,0,Tx],[0,1,Ty]])
result = cv2.warpAffine(img,T,(width,height))
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F228CB05BD0>

# %% [markdown]
# ## Rotate

# %%
height,width = img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((width/2,height/2),180,1)
result = cv2.warpAffine(img,rotation_matrix,(width,height))
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F228CB10C50>

# %% [markdown]
# ## Scaling

# %%
img_scaled = cv2.resize(img,None,fx=2,fy=2)
cv2_imshow(img_scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=600x336 at 0x7F228CB10190>

# %%
img_scaled = cv2.resize(img,(300,300),interpolation = cv2.INTER_AREA)
cv2_imshow(img_scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F228CA94890>

# %%
img_scaled = cv2.resize(img,(300,300),interpolation = cv2.INTER_CUBIC)
cv2_imshow(img_scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F228CA94790>

# %%
height,width = img.shape[:2]
start_row,start_col = int(height*0.35),int(width*0.35)
end_row,end_col = int(height*0.85),int(width*0.75)
crop_img = img[start_row:end_row,start_col:end_col]
# cv2_imshow(img)
cv2_imshow(crop_img)
# Out:
# <PIL.Image.Image image mode=RGB size=120x84 at 0x7F228C8CCC90>

# %%
img3 = np.zeros((200,200),np.uint8)

cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F228C814150>
